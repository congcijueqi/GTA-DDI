# %%
from datetime import datetime
import random

import pandas as pd
import numpy as np
import torch
from torch import nn 
from torch import optim
from torch.utils.data import DataLoader
from sklearn import metrics

import layers
import models
import os
import custom_loss
import time
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
from data_preprocessing import DrugDataset, DrugDataLoader, TOTAL_ATOM_FEATS

# %%
TOTAL_ATOM_FEATS
# Out:
# 55

# %%
df_ddi_train = pd.read_csv('/home/dwj/GTA-DDI/zhangddi-chchddi/data/ddi-data/ZhangDDI_train.csv')
df_ddi_val = pd.read_csv('/home/dwj/GTA-DDI/zhangddi-chchddi/data/ddi-data/ZhangDDI_test.csv')
df_ddi_test = pd.read_csv('/home/dwj/GTA-DDI/zhangddi-chchddi/data/ddi-data/ZhangDDI_valid.csv')

# %%
train_tup = [(h, t, r) for h, t, r in zip(df_ddi_train['drugbank_id_1'], df_ddi_train['drugbank_id_2'], df_ddi_train['label'])]
val_tup = [(h, t, r) for h, t, r in zip(df_ddi_test['drugbank_id_1'], df_ddi_test['drugbank_id_2'], df_ddi_test['label'])]
test_tup = [(h, t, r) for h, t, r in zip(df_ddi_val['drugbank_id_1'], df_ddi_val['drugbank_id_2'], df_ddi_val['label'])]

# %%
len(train_tup)
# Out:
# 68383

# %%
len(val_tup)
# Out:
# 22794

# %%
len(test_tup)
# Out:
# 22795

# %%
total = len(val_tup) + len(train_tup) + len(test_tup)
len(train_tup) / total, len(test_tup)/total, len(val_tup)/total
# Out:
# (0.5999982451830274, 0.20000526445091776, 0.19999649036605482)

# %%
# Hyperparameters
n_atom_feats = TOTAL_ATOM_FEATS
n_atom_hid = 256
rel_total = 1
lr = 1e-4
weight_decay = 5e-4
n_epochs = 300
neg_samples = 1
batch_size = 1024
data_size_ratio = 1
kge_dim = 384

# %%
train_data = DrugDataset(train_tup, ratio=data_size_ratio, neg_ent=neg_samples)

# %%
val_data = DrugDataset(val_tup, ratio=data_size_ratio, disjoint_split=False)
test_data = DrugDataset(test_tup, disjoint_split=False)

# %%
print(f"Training with {len(train_data)} samples, validating with {len(val_data)}, and testing with {len(test_data)}")
# Out:
# Training with 68383 samples, validating with 22794, and testing with 22795

# %%
train_data_loader = DrugDataLoader(train_data, batch_size=batch_size, shuffle=True)
val_data_loader = DrugDataLoader(val_data, batch_size=batch_size *3)
test_data_loader = DrugDataLoader(test_data, batch_size=batch_size *3)

# %%
def do_compute(batch, device, training=True):
        '''
            *batch: (pos_tri, neg_tri)
            *pos/neg_tri: (batch_h, batch_t, batch_r)
        '''
        probas_pred, ground_truth = [], []
        pos_tri = batch
        
        pos_tri = [tensor.to(device=device) for tensor in pos_tri]
        p_score ,rels= model(pos_tri)

        probas_pred = torch.sigmoid(p_score.detach()).cpu()
        ground_truth = rels.cpu().numpy()

        return p_score,probas_pred, ground_truth,rels

# %%
def do_compute_metrics(probas_pred, target):

    pred = (probas_pred >= 0.5).astype(int)

    acc = metrics.accuracy_score(target, pred)
    auc_roc = metrics.roc_auc_score(target, probas_pred)
    f1_score = metrics.f1_score(target, pred)

    p, r, t = metrics.precision_recall_curve(target, probas_pred)
    auc_prc = metrics.auc(r, p)

    return acc, auc_roc, auc_prc

# %%
def train(model, train_data_loader, val_data_loader, loss_fn,  optimizer, n_epochs, device, scheduler=None):
    print('Starting training at', datetime.today())
    for i in range(1, n_epochs+1):
        start = time.time()
        train_loss = 0
        train_loss_pos = 0
        train_loss_neg = 0
        val_loss = 0
        val_loss_pos = 0
        val_loss_neg = 0
        train_probas_pred = []
        train_ground_truth = []
        val_probas_pred = []
        val_ground_truth = []

        for batch in train_data_loader:
            model.train()
            p_score, probas_pred, ground_truth,rels = do_compute(batch, device)
            train_probas_pred.append(probas_pred)
            train_ground_truth.append(ground_truth)
            p_score = p_score.float()
            rels = rels.float()
            loss = loss_fn(p_score,rels )
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * len(p_score)
        train_loss /= len(train_data)

        with torch.no_grad():
            train_probas_pred = np.concatenate(train_probas_pred)
            train_ground_truth = np.concatenate(train_ground_truth)

            train_acc, train_auc_roc, train_auc_prc = do_compute_metrics(train_probas_pred, train_ground_truth)

            for batch in val_data_loader:
                model.eval()
                p_score,  probas_pred, ground_truth,rels = do_compute(batch, device)
                val_probas_pred.append(probas_pred)
                val_ground_truth.append(ground_truth)
                p_score = p_score.float()
                rels = rels.float()
                loss= loss_fn(p_score,rels)
                val_loss += loss.item() * len(p_score)            

            val_loss /= len(val_data)
            val_probas_pred = np.concatenate(val_probas_pred)
            val_ground_truth = np.concatenate(val_ground_truth)
            val_acc, val_auc_roc, val_auc_prc = do_compute_metrics(val_probas_pred, val_ground_truth)
               
        if scheduler:
            print('scheduling')
            scheduler.step()


        output_file = 'training_log.txt'

        with open(output_file, 'a') as f:
            # 写入第一行
            line1 = (f'Epoch: {i} ({time.time() - start:.4f}s), train_loss: {train_loss:.4f}, val_loss: {val_loss:.4f},'
                    f' train_acc: {train_acc:.4f}, val_acc:{val_acc:.4f}')
            print(line1)
            f.write(line1 + '\n')
            
            # 写入第二行
            line2 = (f'\t\ttrain_roc: {train_auc_roc:.4f}, val_roc: {val_auc_roc:.4f}, train_auprc: {train_auc_prc:.4f}, val_auprc: {val_auc_prc:.4f}')
            print(line2)
            f.write(line2 + '\n')

# %%
device = 'cuda:5' if torch.cuda.is_available() else 'cpu'
model = models.GTA_DDI(n_atom_feats, n_atom_hid, kge_dim, rel_total, heads_out_feat_params=[64, 64, 64, 64], blocks_params=[6, 6,6, 6])
loss = custom_loss.SigmoidLoss()
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
scheduler = optim.lr_scheduler.LambdaLR(optimizer, lambda epoch: 0.96 ** (epoch))
model
# Out:
# GTA_DDI(
#   (initial_norm): LayerNorm(55, affine=True, mode=graph)
#   (net_norms): ModuleList(
#     (0-3): 4 x LayerNorm(384, affine=True, mode=graph)
#   )
#   (block0): GTA_DDI_Block(
#     (conv): GATConv(55, 64, heads=6)
#     (readout): TopKPooling(384, ratio=0.5, multiplier=1.0)
#   )
#   (block1): GTA_DDI_Block(
#     (conv): GATConv(384, 64, heads=6)
#     (readout): TopKPooling(384, ratio=0.5, multiplier=1.0)
#   )
#   (block2): GTA_DDI_Block(
#     (conv): GATConv(384, 64, heads=6)
#     (readout): TopKPooling(384, ratio=0.5, multiplier=1.0)
#   )
#   (block3): GTA_DDI_Block(
#     (conv): GATConv(384, 64, heads=6)
#     (readout): TopKPooling(384, ratio=0.5, multiplier=1.0)
#   )
#   (co_attention): CoAttentionLayer()
#   (KGE): RESCAL(1, torch.Size([1, 147456]))
# )

# %%
model.to(device=device);

# %%
train(model, train_data_loader, val_data_loader, loss, optimizer, n_epochs, device, scheduler)
# Out:
# Starting training at 2024-06-21 00:57:23.485165
# scheduling
# Epoch: 1 (115.4607s), train_loss: 0.6435, val_loss: 0.6049, train_acc: 0.6265, val_acc:0.6660
# 		train_roc: 0.6357, val_roc: 0.7221, train_auprc: 0.5287, val_auprc: 0.6314
# scheduling
# Epoch: 2 (126.3425s), train_loss: 0.5613, val_loss: 0.5193, train_acc: 0.7115, val_acc:0.7517
# 		train_roc: 0.7729, val_roc: 0.8205, train_auprc: 0.6901, val_auprc: 0.7627
# scheduling
# Epoch: 3 (125.9905s), train_loss: 0.4961, val_loss: 0.4712, train_acc: 0.7630, val_acc:0.7839
# 		train_roc: 0.8336, val_roc: 0.8566, train_auprc: 0.7749, val_auprc: 0.8087
# scheduling
# Epoch: 4 (126.3196s), train_loss: 0.4638, val_loss: 0.4467, train_acc: 0.7845, val_acc:0.7936
# 		train_roc: 0.8575, val_roc: 0.8764, train_auprc: 0.8079, val_auprc: 0.8366
# scheduling
# Epoch: 5 (126.3211s), train_loss: 0.4358, val_loss: 0.4290, train_acc: 0.8013, val_acc:0.8099
# 		train_roc: 0.8756, val_roc: 0.8807, train_auprc: 0.8336, val_auprc: 0.8452
# scheduling
# Epoch: 6 (126.6871s), train_loss: 0.4338, val_loss: 0.4154, train_acc: 0.8007, val_acc:0.8129
# 		train_roc: 0.8761, val_roc: 0.8899, train_auprc: 0.8339, val_auprc: 0.8566
# scheduling
# Epoch: 7 (126.0702s), train_loss: 0.4092, val_loss: 0.4063, train_acc: 0.8153, val_acc:0.8173
# 		train_roc: 0.8912, val_roc: 0.8933, train_auprc: 0.8546, val_auprc: 0.8607
# scheduling
# Epoch: 8 (126.6846s), train_loss: 0.3923, val_loss: 0.3896, train_acc: 0.8249, val_acc:0.8268
# 		train_roc: 0.9008, val_roc: 0.9029, train_auprc: 0.8688, val_auprc: 0.8756
# scheduling
# Epoch: 9 (126.4158s), train_loss: 0.3883, val_loss: 0.3785, train_acc: 0.8271, val_acc:0.8344
# 		train_roc: 0.9025, val_roc: 0.9101, train_auprc: 0.8705, val_auprc: 0.8861
# scheduling
# Epoch: 10 (125.6361s), train_loss: 0.3812, val_loss: 0.3854, train_acc: 0.8301, val_acc:0.8302
# 		train_roc: 0.9061, val_roc: 0.9080, train_auprc: 0.8758, val_auprc: 0.8809
# scheduling
# Epoch: 11 (126.6244s), train_loss: 0.3747, val_loss: 0.3913, train_acc: 0.8340, val_acc:0.8269
# 		train_roc: 0.9096, val_roc: 0.9028, train_auprc: 0.8795, val_auprc: 0.8754
# scheduling
# Epoch: 12 (125.9529s), train_loss: 0.3769, val_loss: 0.3699, train_acc: 0.8331, val_acc:0.8389
# 		train_roc: 0.9085, val_roc: 0.9165, train_auprc: 0.8789, val_auprc: 0.8927
# scheduling
# Epoch: 13 (125.2463s), train_loss: 0.3627, val_loss: 0.3552, train_acc: 0.8404, val_acc:0.8468
# 		train_roc: 0.9154, val_roc: 0.9202, train_auprc: 0.8886, val_auprc: 0.8991
# scheduling
# Epoch: 14 (126.0082s), train_loss: 0.3516, val_loss: 0.3464, train_acc: 0.8464, val_acc:0.8504
# 		train_roc: 0.9209, val_roc: 0.9240, train_auprc: 0.8961, val_auprc: 0.9036
# scheduling
# Epoch: 15 (126.2144s), train_loss: 0.3503, val_loss: 0.3531, train_acc: 0.8473, val_acc:0.8479
# 		train_roc: 0.9212, val_roc: 0.9208, train_auprc: 0.8966, val_auprc: 0.8996
# scheduling
# Epoch: 16 (125.9375s), train_loss: 0.3489, val_loss: 0.3443, train_acc: 0.8479, val_acc:0.8510
# 		train_roc: 0.9217, val_roc: 0.9248, train_auprc: 0.8975, val_auprc: 0.9054
# scheduling
# Epoch: 17 (126.2925s), train_loss: 0.3392, val_loss: 0.3344, train_acc: 0.8523, val_acc:0.8551
# 		train_roc: 0.9262, val_roc: 0.9289, train_auprc: 0.9036, val_auprc: 0.9110
# scheduling
# Epoch: 18 (124.7356s), train_loss: 0.3371, val_loss: 0.3385, train_acc: 0.8539, val_acc:0.8561
# 		train_roc: 0.9269, val_roc: 0.9283, train_auprc: 0.9049, val_auprc: 0.9108
# scheduling
# Epoch: 19 (126.1381s), train_loss: 0.3320, val_loss: 0.3317, train_acc: 0.8564, val_acc:0.8547
# 		train_roc: 0.9295, val_roc: 0.9309, train_auprc: 0.9082, val_auprc: 0.9131
# scheduling
# Epoch: 20 (126.3792s), train_loss: 0.3282, val_loss: 0.3319, train_acc: 0.8583, val_acc:0.8559
# 		train_roc: 0.9308, val_roc: 0.9308, train_auprc: 0.9102, val_auprc: 0.9132
# scheduling
# Epoch: 21 (126.0012s), train_loss: 0.3267, val_loss: 0.3324, train_acc: 0.8576, val_acc:0.8574
# 		train_roc: 0.9316, val_roc: 0.9301, train_auprc: 0.9108, val_auprc: 0.9123
# scheduling
# Epoch: 22 (125.4155s), train_loss: 0.3248, val_loss: 0.3240, train_acc: 0.8610, val_acc:0.8606
# 		train_roc: 0.9324, val_roc: 0.9334, train_auprc: 0.9122, val_auprc: 0.9161
# scheduling
# Epoch: 23 (126.1309s), train_loss: 0.3218, val_loss: 0.3283, train_acc: 0.8622, val_acc:0.8579
# 		train_roc: 0.9336, val_roc: 0.9315, train_auprc: 0.9137, val_auprc: 0.9139
# scheduling
# Epoch: 24 (126.6375s), train_loss: 0.3230, val_loss: 0.3249, train_acc: 0.8616, val_acc:0.8638
# 		train_roc: 0.9329, val_roc: 0.9350, train_auprc: 0.9126, val_auprc: 0.9189
# scheduling
# Epoch: 25 (126.7233s), train_loss: 0.3241, val_loss: 0.3261, train_acc: 0.8607, val_acc:0.8612
# 		train_roc: 0.9324, val_roc: 0.9324, train_auprc: 0.9116, val_auprc: 0.9160
# scheduling
# Epoch: 26 (126.6046s), train_loss: 0.3218, val_loss: 0.3188, train_acc: 0.8614, val_acc:0.8644
# 		train_roc: 0.9334, val_roc: 0.9352, train_auprc: 0.9140, val_auprc: 0.9193
# scheduling
# Epoch: 27 (126.7603s), train_loss: 0.3200, val_loss: 0.3219, train_acc: 0.8627, val_acc:0.8609
# 		train_roc: 0.9342, val_roc: 0.9337, train_auprc: 0.9148, val_auprc: 0.9175
# scheduling
# Epoch: 28 (126.3241s), train_loss: 0.3164, val_loss: 0.3154, train_acc: 0.8642, val_acc:0.8662
# 		train_roc: 0.9357, val_roc: 0.9366, train_auprc: 0.9169, val_auprc: 0.9212
# scheduling
# Epoch: 29 (126.5387s), train_loss: 0.3140, val_loss: 0.3175, train_acc: 0.8657, val_acc:0.8647
# 		train_roc: 0.9367, val_roc: 0.9355, train_auprc: 0.9181, val_auprc: 0.9194
# scheduling
# Epoch: 30 (126.8688s), train_loss: 0.3156, val_loss: 0.3189, train_acc: 0.8637, val_acc:0.8607
# 		train_roc: 0.9358, val_roc: 0.9357, train_auprc: 0.9170, val_auprc: 0.9202
# scheduling
# Epoch: 31 (126.4757s), train_loss: 0.3149, val_loss: 0.3169, train_acc: 0.8643, val_acc:0.8652
# 		train_roc: 0.9361, val_roc: 0.9368, train_auprc: 0.9173, val_auprc: 0.9210
# scheduling
# Epoch: 32 (126.6396s), train_loss: 0.3120, val_loss: 0.3138, train_acc: 0.8664, val_acc:0.8666
# 		train_roc: 0.9375, val_roc: 0.9372, train_auprc: 0.9191, val_auprc: 0.9221
# scheduling
# Epoch: 33 (125.9663s), train_loss: 0.3121, val_loss: 0.3137, train_acc: 0.8658, val_acc:0.8665
# 		train_roc: 0.9374, val_roc: 0.9372, train_auprc: 0.9192, val_auprc: 0.9218
# scheduling
# Epoch: 34 (126.3899s), train_loss: 0.3093, val_loss: 0.3135, train_acc: 0.8679, val_acc:0.8661
# 		train_roc: 0.9386, val_roc: 0.9372, train_auprc: 0.9206, val_auprc: 0.9217
# scheduling
# Epoch: 35 (126.6240s), train_loss: 0.3103, val_loss: 0.3116, train_acc: 0.8661, val_acc:0.8672
# 		train_roc: 0.9380, val_roc: 0.9379, train_auprc: 0.9200, val_auprc: 0.9227
# scheduling
# Epoch: 36 (126.4432s), train_loss: 0.3085, val_loss: 0.3100, train_acc: 0.8683, val_acc:0.8688
# 		train_roc: 0.9388, val_roc: 0.9385, train_auprc: 0.9211, val_auprc: 0.9241
# scheduling
# Epoch: 37 (126.8463s), train_loss: 0.3069, val_loss: 0.3077, train_acc: 0.8681, val_acc:0.8682
# 		train_roc: 0.9393, val_roc: 0.9395, train_auprc: 0.9218, val_auprc: 0.9253
# scheduling
# Epoch: 38 (126.3786s), train_loss: 0.3046, val_loss: 0.3081, train_acc: 0.8709, val_acc:0.8693
# 		train_roc: 0.9404, val_roc: 0.9397, train_auprc: 0.9233, val_auprc: 0.9258
# scheduling
# Epoch: 39 (126.8530s), train_loss: 0.3059, val_loss: 0.3103, train_acc: 0.8692, val_acc:0.8665
# 		train_roc: 0.9397, val_roc: 0.9385, train_auprc: 0.9224, val_auprc: 0.9240
# scheduling
# Epoch: 40 (126.3777s), train_loss: 0.3040, val_loss: 0.3065, train_acc: 0.8701, val_acc:0.8680
# 		train_roc: 0.9404, val_roc: 0.9399, train_auprc: 0.9235, val_auprc: 0.9252
# scheduling
# Epoch: 41 (127.5671s), train_loss: 0.3046, val_loss: 0.3084, train_acc: 0.8704, val_acc:0.8705
# 		train_roc: 0.9403, val_roc: 0.9390, train_auprc: 0.9231, val_auprc: 0.9247
# scheduling
# Epoch: 42 (127.1790s), train_loss: 0.3035, val_loss: 0.3080, train_acc: 0.8704, val_acc:0.8686
# 		train_roc: 0.9408, val_roc: 0.9394, train_auprc: 0.9237, val_auprc: 0.9251
# scheduling
# Epoch: 43 (125.9665s), train_loss: 0.3042, val_loss: 0.3076, train_acc: 0.8692, val_acc:0.8672
# 		train_roc: 0.9405, val_roc: 0.9395, train_auprc: 0.9234, val_auprc: 0.9250
# scheduling
# Epoch: 44 (126.6340s), train_loss: 0.3034, val_loss: 0.3081, train_acc: 0.8707, val_acc:0.8677
# 		train_roc: 0.9408, val_roc: 0.9393, train_auprc: 0.9236, val_auprc: 0.9243
# scheduling
# Epoch: 45 (126.5551s), train_loss: 0.3030, val_loss: 0.3048, train_acc: 0.8709, val_acc:0.8697
# 		train_roc: 0.9409, val_roc: 0.9407, train_auprc: 0.9238, val_auprc: 0.9262
# scheduling
# Epoch: 46 (126.8168s), train_loss: 0.3028, val_loss: 0.3037, train_acc: 0.8717, val_acc:0.8701
# 		train_roc: 0.9410, val_roc: 0.9411, train_auprc: 0.9240, val_auprc: 0.9268
# scheduling
# Epoch: 47 (126.8066s), train_loss: 0.2999, val_loss: 0.3026, train_acc: 0.8724, val_acc:0.8721
# 		train_roc: 0.9423, val_roc: 0.9416, train_auprc: 0.9255, val_auprc: 0.9277
# scheduling
# Epoch: 48 (126.3334s), train_loss: 0.2991, val_loss: 0.3041, train_acc: 0.8733, val_acc:0.8697
# 		train_roc: 0.9425, val_roc: 0.9408, train_auprc: 0.9260, val_auprc: 0.9264
# scheduling
# Epoch: 49 (127.3266s), train_loss: 0.2993, val_loss: 0.3028, train_acc: 0.8721, val_acc:0.8720
# 		train_roc: 0.9424, val_roc: 0.9414, train_auprc: 0.9257, val_auprc: 0.9272
# scheduling
# Epoch: 50 (126.9707s), train_loss: 0.2996, val_loss: 0.3027, train_acc: 0.8724, val_acc:0.8699
# 		train_roc: 0.9423, val_roc: 0.9415, train_auprc: 0.9255, val_auprc: 0.9274
# scheduling
# Epoch: 51 (127.2071s), train_loss: 0.2977, val_loss: 0.3034, train_acc: 0.8730, val_acc:0.8702
# 		train_roc: 0.9430, val_roc: 0.9413, train_auprc: 0.9268, val_auprc: 0.9274
# scheduling
# Epoch: 52 (126.9545s), train_loss: 0.2974, val_loss: 0.3010, train_acc: 0.8731, val_acc:0.8725
# 		train_roc: 0.9432, val_roc: 0.9421, train_auprc: 0.9267, val_auprc: 0.9283
# scheduling
# Epoch: 53 (126.7547s), train_loss: 0.2960, val_loss: 0.3005, train_acc: 0.8736, val_acc:0.8712
# 		train_roc: 0.9437, val_roc: 0.9422, train_auprc: 0.9279, val_auprc: 0.9283
# scheduling
# Epoch: 54 (127.0336s), train_loss: 0.2958, val_loss: 0.3026, train_acc: 0.8736, val_acc:0.8703
# 		train_roc: 0.9437, val_roc: 0.9414, train_auprc: 0.9278, val_auprc: 0.9273
# scheduling
# Epoch: 55 (127.2783s), train_loss: 0.2956, val_loss: 0.3021, train_acc: 0.8744, val_acc:0.8721
# 		train_roc: 0.9439, val_roc: 0.9416, train_auprc: 0.9281, val_auprc: 0.9273
# scheduling
# Epoch: 56 (126.7954s), train_loss: 0.2952, val_loss: 0.3006, train_acc: 0.8737, val_acc:0.8721
# 		train_roc: 0.9439, val_roc: 0.9421, train_auprc: 0.9282, val_auprc: 0.9283
# scheduling
# Epoch: 57 (126.8466s), train_loss: 0.2948, val_loss: 0.2993, train_acc: 0.8739, val_acc:0.8726
# 		train_roc: 0.9441, val_roc: 0.9426, train_auprc: 0.9283, val_auprc: 0.9292
# scheduling
# Epoch: 58 (126.5476s), train_loss: 0.2941, val_loss: 0.2993, train_acc: 0.8747, val_acc:0.8729
# 		train_roc: 0.9444, val_roc: 0.9427, train_auprc: 0.9286, val_auprc: 0.9290
# scheduling
# Epoch: 59 (127.1133s), train_loss: 0.2934, val_loss: 0.3003, train_acc: 0.8753, val_acc:0.8729
# 		train_roc: 0.9447, val_roc: 0.9423, train_auprc: 0.9288, val_auprc: 0.9290
# scheduling
# Epoch: 60 (127.2299s), train_loss: 0.2925, val_loss: 0.2998, train_acc: 0.8754, val_acc:0.8727
# 		train_roc: 0.9450, val_roc: 0.9427, train_auprc: 0.9295, val_auprc: 0.9292
# scheduling
# Epoch: 61 (126.7357s), train_loss: 0.2931, val_loss: 0.2996, train_acc: 0.8757, val_acc:0.8732
# 		train_roc: 0.9448, val_roc: 0.9427, train_auprc: 0.9290, val_auprc: 0.9293
# scheduling
# Epoch: 62 (126.7045s), train_loss: 0.2927, val_loss: 0.2994, train_acc: 0.8752, val_acc:0.8731
# 		train_roc: 0.9449, val_roc: 0.9427, train_auprc: 0.9295, val_auprc: 0.9295
# scheduling
# Epoch: 63 (126.6458s), train_loss: 0.2926, val_loss: 0.2987, train_acc: 0.8747, val_acc:0.8735
# 		train_roc: 0.9449, val_roc: 0.9429, train_auprc: 0.9293, val_auprc: 0.9298
# scheduling
# Epoch: 64 (125.9907s), train_loss: 0.2917, val_loss: 0.2999, train_acc: 0.8755, val_acc:0.8725
# 		train_roc: 0.9453, val_roc: 0.9424, train_auprc: 0.9297, val_auprc: 0.9290
# scheduling
# Epoch: 65 (127.2559s), train_loss: 0.2911, val_loss: 0.2978, train_acc: 0.8756, val_acc:0.8733
# 		train_roc: 0.9455, val_roc: 0.9431, train_auprc: 0.9301, val_auprc: 0.9301
# scheduling
# Epoch: 66 (127.2955s), train_loss: 0.2918, val_loss: 0.3004, train_acc: 0.8752, val_acc:0.8732
# 		train_roc: 0.9453, val_roc: 0.9426, train_auprc: 0.9300, val_auprc: 0.9292
# scheduling
# Epoch: 67 (127.3583s), train_loss: 0.2903, val_loss: 0.2973, train_acc: 0.8765, val_acc:0.8747
# 		train_roc: 0.9459, val_roc: 0.9433, train_auprc: 0.9304, val_auprc: 0.9303
# scheduling
# Epoch: 68 (126.7548s), train_loss: 0.2915, val_loss: 0.2992, train_acc: 0.8762, val_acc:0.8726
# 		train_roc: 0.9454, val_roc: 0.9428, train_auprc: 0.9299, val_auprc: 0.9296
# scheduling
# Epoch: 69 (125.8504s), train_loss: 0.2905, val_loss: 0.2972, train_acc: 0.8759, val_acc:0.8746
# 		train_roc: 0.9458, val_roc: 0.9435, train_auprc: 0.9307, val_auprc: 0.9304
# scheduling
# Epoch: 70 (126.7400s), train_loss: 0.2902, val_loss: 0.2969, train_acc: 0.8765, val_acc:0.8747
# 		train_roc: 0.9458, val_roc: 0.9435, train_auprc: 0.9306, val_auprc: 0.9305
# scheduling
# Epoch: 71 (126.5636s), train_loss: 0.2895, val_loss: 0.2976, train_acc: 0.8772, val_acc:0.8736
# 		train_roc: 0.9462, val_roc: 0.9432, train_auprc: 0.9311, val_auprc: 0.9301
# scheduling
# Epoch: 72 (126.4795s), train_loss: 0.2897, val_loss: 0.2988, train_acc: 0.8776, val_acc:0.8725
# 		train_roc: 0.9461, val_roc: 0.9430, train_auprc: 0.9309, val_auprc: 0.9298
# scheduling
# Epoch: 73 (126.6205s), train_loss: 0.2895, val_loss: 0.2969, train_acc: 0.8772, val_acc:0.8731
# 		train_roc: 0.9461, val_roc: 0.9435, train_auprc: 0.9310, val_auprc: 0.9307
# scheduling
# Epoch: 74 (126.8217s), train_loss: 0.2888, val_loss: 0.2974, train_acc: 0.8773, val_acc:0.8742
# 		train_roc: 0.9464, val_roc: 0.9436, train_auprc: 0.9315, val_auprc: 0.9305
# scheduling
# Epoch: 75 (126.8069s), train_loss: 0.2900, val_loss: 0.2971, train_acc: 0.8766, val_acc:0.8741
# 		train_roc: 0.9459, val_roc: 0.9434, train_auprc: 0.9308, val_auprc: 0.9303
# scheduling
# Epoch: 76 (127.6789s), train_loss: 0.2892, val_loss: 0.2965, train_acc: 0.8771, val_acc:0.8735
# 		train_roc: 0.9462, val_roc: 0.9436, train_auprc: 0.9313, val_auprc: 0.9304
# scheduling
# Epoch: 77 (127.1105s), train_loss: 0.2899, val_loss: 0.2970, train_acc: 0.8769, val_acc:0.8736
# 		train_roc: 0.9459, val_roc: 0.9434, train_auprc: 0.9308, val_auprc: 0.9301
# scheduling
# Epoch: 78 (126.6907s), train_loss: 0.2896, val_loss: 0.2968, train_acc: 0.8772, val_acc:0.8734
# 		train_roc: 0.9460, val_roc: 0.9435, train_auprc: 0.9309, val_auprc: 0.9305
# scheduling
# Epoch: 79 (126.9376s), train_loss: 0.2888, val_loss: 0.2975, train_acc: 0.8777, val_acc:0.8737
# 		train_roc: 0.9464, val_roc: 0.9434, train_auprc: 0.9313, val_auprc: 0.9307
# scheduling
# Epoch: 80 (127.0980s), train_loss: 0.2900, val_loss: 0.2975, train_acc: 0.8760, val_acc:0.8732
# 		train_roc: 0.9459, val_roc: 0.9433, train_auprc: 0.9309, val_auprc: 0.9301
# scheduling
# Epoch: 81 (126.9763s), train_loss: 0.2887, val_loss: 0.2969, train_acc: 0.8771, val_acc:0.8731
# 		train_roc: 0.9465, val_roc: 0.9435, train_auprc: 0.9313, val_auprc: 0.9307
# scheduling
# Epoch: 82 (126.6488s), train_loss: 0.2879, val_loss: 0.2964, train_acc: 0.8776, val_acc:0.8746
# 		train_roc: 0.9468, val_roc: 0.9437, train_auprc: 0.9320, val_auprc: 0.9309
# scheduling
# Epoch: 83 (126.7306s), train_loss: 0.2879, val_loss: 0.2974, train_acc: 0.8774, val_acc:0.8733
# 		train_roc: 0.9468, val_roc: 0.9434, train_auprc: 0.9319, val_auprc: 0.9304
# scheduling
# Epoch: 84 (126.7921s), train_loss: 0.2874, val_loss: 0.2967, train_acc: 0.8784, val_acc:0.8754
# 		train_roc: 0.9469, val_roc: 0.9436, train_auprc: 0.9319, val_auprc: 0.9307
# scheduling
# Epoch: 85 (127.6044s), train_loss: 0.2878, val_loss: 0.2962, train_acc: 0.8775, val_acc:0.8742
# 		train_roc: 0.9468, val_roc: 0.9437, train_auprc: 0.9321, val_auprc: 0.9310
# scheduling
# Epoch: 86 (126.0387s), train_loss: 0.2871, val_loss: 0.2969, train_acc: 0.8781, val_acc:0.8748
# 		train_roc: 0.9470, val_roc: 0.9437, train_auprc: 0.9322, val_auprc: 0.9309
# scheduling
# Epoch: 87 (127.5538s), train_loss: 0.2885, val_loss: 0.2970, train_acc: 0.8771, val_acc:0.8743
# 		train_roc: 0.9465, val_roc: 0.9436, train_auprc: 0.9315, val_auprc: 0.9306
# scheduling
# Epoch: 88 (125.4249s), train_loss: 0.2871, val_loss: 0.2965, train_acc: 0.8782, val_acc:0.8746
# 		train_roc: 0.9471, val_roc: 0.9437, train_auprc: 0.9321, val_auprc: 0.9307
# scheduling
# Epoch: 89 (127.4444s), train_loss: 0.2867, val_loss: 0.2961, train_acc: 0.8784, val_acc:0.8744
# 		train_roc: 0.9472, val_roc: 0.9437, train_auprc: 0.9324, val_auprc: 0.9309
# scheduling
# Epoch: 90 (127.2955s), train_loss: 0.2862, val_loss: 0.2954, train_acc: 0.8786, val_acc:0.8738
# 		train_roc: 0.9474, val_roc: 0.9440, train_auprc: 0.9328, val_auprc: 0.9312
# scheduling
# Epoch: 91 (127.4656s), train_loss: 0.2863, val_loss: 0.2951, train_acc: 0.8777, val_acc:0.8746
# 		train_roc: 0.9473, val_roc: 0.9441, train_auprc: 0.9327, val_auprc: 0.9315
# scheduling
# Epoch: 92 (126.7117s), train_loss: 0.2862, val_loss: 0.2949, train_acc: 0.8797, val_acc:0.8745
# 		train_roc: 0.9474, val_roc: 0.9442, train_auprc: 0.9325, val_auprc: 0.9316
# scheduling
# Epoch: 93 (126.5491s), train_loss: 0.2858, val_loss: 0.2957, train_acc: 0.8786, val_acc:0.8743
# 		train_roc: 0.9475, val_roc: 0.9439, train_auprc: 0.9328, val_auprc: 0.9313
# scheduling
# Epoch: 94 (127.0011s), train_loss: 0.2859, val_loss: 0.2950, train_acc: 0.8787, val_acc:0.8749
# 		train_roc: 0.9475, val_roc: 0.9441, train_auprc: 0.9329, val_auprc: 0.9315
# scheduling
# Epoch: 95 (126.6954s), train_loss: 0.2860, val_loss: 0.2946, train_acc: 0.8785, val_acc:0.8762
# 		train_roc: 0.9474, val_roc: 0.9445, train_auprc: 0.9328, val_auprc: 0.9319
# scheduling
# Epoch: 96 (127.4577s), train_loss: 0.2855, val_loss: 0.2949, train_acc: 0.8788, val_acc:0.8752
# 		train_roc: 0.9476, val_roc: 0.9442, train_auprc: 0.9333, val_auprc: 0.9315
# scheduling
# Epoch: 97 (126.7320s), train_loss: 0.2853, val_loss: 0.2940, train_acc: 0.8791, val_acc:0.8753
# 		train_roc: 0.9477, val_roc: 0.9446, train_auprc: 0.9330, val_auprc: 0.9319
# scheduling
# Epoch: 98 (126.2322s), train_loss: 0.2859, val_loss: 0.2944, train_acc: 0.8794, val_acc:0.8751
# 		train_roc: 0.9475, val_roc: 0.9444, train_auprc: 0.9327, val_auprc: 0.9318
# scheduling
# Epoch: 99 (126.6093s), train_loss: 0.2863, val_loss: 0.2944, train_acc: 0.8779, val_acc:0.8753
# 		train_roc: 0.9473, val_roc: 0.9445, train_auprc: 0.9323, val_auprc: 0.9319
# scheduling
# Epoch: 100 (126.0456s), train_loss: 0.2855, val_loss: 0.2951, train_acc: 0.8785, val_acc:0.8757
# 		train_roc: 0.9477, val_roc: 0.9441, train_auprc: 0.9330, val_auprc: 0.9315
# scheduling
# Epoch: 101 (124.7138s), train_loss: 0.2850, val_loss: 0.2942, train_acc: 0.8795, val_acc:0.8758
# 		train_roc: 0.9479, val_roc: 0.9445, train_auprc: 0.9333, val_auprc: 0.9319
# scheduling
# Epoch: 102 (126.7531s), train_loss: 0.2852, val_loss: 0.2946, train_acc: 0.8782, val_acc:0.8754
# 		train_roc: 0.9477, val_roc: 0.9443, train_auprc: 0.9332, val_auprc: 0.9316
# scheduling
# Epoch: 103 (126.4320s), train_loss: 0.2864, val_loss: 0.2942, train_acc: 0.8781, val_acc:0.8754
# 		train_roc: 0.9473, val_roc: 0.9445, train_auprc: 0.9326, val_auprc: 0.9319
# scheduling
# Epoch: 104 (125.9535s), train_loss: 0.2848, val_loss: 0.2941, train_acc: 0.8792, val_acc:0.8756
# 		train_roc: 0.9479, val_roc: 0.9445, train_auprc: 0.9332, val_auprc: 0.9319
# scheduling
# Epoch: 105 (127.5186s), train_loss: 0.2853, val_loss: 0.2936, train_acc: 0.8795, val_acc:0.8757
# 		train_roc: 0.9477, val_roc: 0.9447, train_auprc: 0.9331, val_auprc: 0.9320
# scheduling
# Epoch: 106 (126.6522s), train_loss: 0.2848, val_loss: 0.2940, train_acc: 0.8796, val_acc:0.8764
# 		train_roc: 0.9479, val_roc: 0.9446, train_auprc: 0.9332, val_auprc: 0.9321
# scheduling
# Epoch: 107 (127.0739s), train_loss: 0.2862, val_loss: 0.2941, train_acc: 0.8784, val_acc:0.8758
# 		train_roc: 0.9474, val_roc: 0.9445, train_auprc: 0.9326, val_auprc: 0.9318
# scheduling
# Epoch: 108 (126.2421s), train_loss: 0.2856, val_loss: 0.2947, train_acc: 0.8790, val_acc:0.8744
# 		train_roc: 0.9476, val_roc: 0.9443, train_auprc: 0.9330, val_auprc: 0.9315
# scheduling
# Epoch: 109 (126.5781s), train_loss: 0.2860, val_loss: 0.2942, train_acc: 0.8785, val_acc:0.8749
# 		train_roc: 0.9475, val_roc: 0.9445, train_auprc: 0.9326, val_auprc: 0.9317
# scheduling
# Epoch: 110 (125.3506s), train_loss: 0.2847, val_loss: 0.2944, train_acc: 0.8798, val_acc:0.8747
# 		train_roc: 0.9479, val_roc: 0.9444, train_auprc: 0.9334, val_auprc: 0.9316
# scheduling
# Epoch: 111 (127.2798s), train_loss: 0.2860, val_loss: 0.2942, train_acc: 0.8790, val_acc:0.8752
# 		train_roc: 0.9475, val_roc: 0.9444, train_auprc: 0.9326, val_auprc: 0.9317
# scheduling
# Epoch: 112 (126.2677s), train_loss: 0.2855, val_loss: 0.2942, train_acc: 0.8788, val_acc:0.8746
# 		train_roc: 0.9476, val_roc: 0.9445, train_auprc: 0.9330, val_auprc: 0.9316
# scheduling
# Epoch: 113 (126.5621s), train_loss: 0.2855, val_loss: 0.2945, train_acc: 0.8788, val_acc:0.8748
# 		train_roc: 0.9476, val_roc: 0.9443, train_auprc: 0.9328, val_auprc: 0.9315
# scheduling
# Epoch: 114 (125.7376s), train_loss: 0.2848, val_loss: 0.2941, train_acc: 0.8790, val_acc:0.8755
# 		train_roc: 0.9479, val_roc: 0.9445, train_auprc: 0.9334, val_auprc: 0.9317
# scheduling
# Epoch: 115 (126.4654s), train_loss: 0.2849, val_loss: 0.2945, train_acc: 0.8790, val_acc:0.8752
# 		train_roc: 0.9478, val_roc: 0.9444, train_auprc: 0.9334, val_auprc: 0.9317
# scheduling
# Epoch: 116 (126.0309s), train_loss: 0.2847, val_loss: 0.2943, train_acc: 0.8791, val_acc:0.8750
# 		train_roc: 0.9480, val_roc: 0.9445, train_auprc: 0.9334, val_auprc: 0.9318
# scheduling
# Epoch: 117 (127.2077s), train_loss: 0.2844, val_loss: 0.2942, train_acc: 0.8790, val_acc:0.8753
# 		train_roc: 0.9480, val_roc: 0.9444, train_auprc: 0.9337, val_auprc: 0.9318
# scheduling
# Epoch: 118 (126.5737s), train_loss: 0.2838, val_loss: 0.2942, train_acc: 0.8799, val_acc:0.8740
# 		train_roc: 0.9483, val_roc: 0.9444, train_auprc: 0.9340, val_auprc: 0.9317
# scheduling
# Epoch: 119 (126.7935s), train_loss: 0.2848, val_loss: 0.2938, train_acc: 0.8789, val_acc:0.8751
# 		train_roc: 0.9479, val_roc: 0.9445, train_auprc: 0.9333, val_auprc: 0.9318
# scheduling
# Epoch: 120 (126.8434s), train_loss: 0.2852, val_loss: 0.2938, train_acc: 0.8785, val_acc:0.8752
# 		train_roc: 0.9477, val_roc: 0.9446, train_auprc: 0.9331, val_auprc: 0.9319
# scheduling
# Epoch: 121 (126.7219s), train_loss: 0.2845, val_loss: 0.2941, train_acc: 0.8798, val_acc:0.8749
# 		train_roc: 0.9480, val_roc: 0.9445, train_auprc: 0.9334, val_auprc: 0.9318
# scheduling
# Epoch: 122 (126.8463s), train_loss: 0.2839, val_loss: 0.2937, train_acc: 0.8807, val_acc:0.8751
# 		train_roc: 0.9483, val_roc: 0.9446, train_auprc: 0.9338, val_auprc: 0.9320
# scheduling
# Epoch: 123 (126.8457s), train_loss: 0.2846, val_loss: 0.2939, train_acc: 0.8802, val_acc:0.8748
# 		train_roc: 0.9480, val_roc: 0.9446, train_auprc: 0.9335, val_auprc: 0.9319
# scheduling
# Epoch: 124 (125.7990s), train_loss: 0.2846, val_loss: 0.2941, train_acc: 0.8787, val_acc:0.8753
# 		train_roc: 0.9479, val_roc: 0.9445, train_auprc: 0.9334, val_auprc: 0.9318
# scheduling
# Epoch: 125 (126.6923s), train_loss: 0.2850, val_loss: 0.2943, train_acc: 0.8787, val_acc:0.8754
# 		train_roc: 0.9478, val_roc: 0.9445, train_auprc: 0.9333, val_auprc: 0.9318
# scheduling
# Epoch: 126 (126.0184s), train_loss: 0.2842, val_loss: 0.2941, train_acc: 0.8799, val_acc:0.8751
# 		train_roc: 0.9481, val_roc: 0.9445, train_auprc: 0.9338, val_auprc: 0.9318
# scheduling
# Epoch: 127 (125.3848s), train_loss: 0.2842, val_loss: 0.2940, train_acc: 0.8798, val_acc:0.8758
# 		train_roc: 0.9482, val_roc: 0.9446, train_auprc: 0.9339, val_auprc: 0.9319
# scheduling
# Epoch: 128 (126.1363s), train_loss: 0.2848, val_loss: 0.2940, train_acc: 0.8794, val_acc:0.8744
# 		train_roc: 0.9479, val_roc: 0.9445, train_auprc: 0.9334, val_auprc: 0.9317
# scheduling
# Epoch: 129 (126.6792s), train_loss: 0.2846, val_loss: 0.2943, train_acc: 0.8786, val_acc:0.8753
# 		train_roc: 0.9480, val_roc: 0.9445, train_auprc: 0.9335, val_auprc: 0.9318
# scheduling
# Epoch: 130 (126.9532s), train_loss: 0.2852, val_loss: 0.2941, train_acc: 0.8786, val_acc:0.8753
# 		train_roc: 0.9478, val_roc: 0.9446, train_auprc: 0.9331, val_auprc: 0.9318
# scheduling
# Epoch: 131 (126.8454s), train_loss: 0.2845, val_loss: 0.2944, train_acc: 0.8793, val_acc:0.8749
# 		train_roc: 0.9480, val_roc: 0.9444, train_auprc: 0.9335, val_auprc: 0.9316
# scheduling
# Epoch: 132 (126.6233s), train_loss: 0.2846, val_loss: 0.2939, train_acc: 0.8798, val_acc:0.8754
# 		train_roc: 0.9479, val_roc: 0.9446, train_auprc: 0.9336, val_auprc: 0.9319
# scheduling
# Epoch: 133 (126.4702s), train_loss: 0.2841, val_loss: 0.2941, train_acc: 0.8797, val_acc:0.8756
# 		train_roc: 0.9482, val_roc: 0.9446, train_auprc: 0.9337, val_auprc: 0.9319
# scheduling
# Epoch: 134 (126.7693s), train_loss: 0.2848, val_loss: 0.2938, train_acc: 0.8791, val_acc:0.8751
# 		train_roc: 0.9479, val_roc: 0.9447, train_auprc: 0.9333, val_auprc: 0.9320
# scheduling
# Epoch: 135 (126.9611s), train_loss: 0.2843, val_loss: 0.2939, train_acc: 0.8795, val_acc:0.8761
# 		train_roc: 0.9481, val_roc: 0.9446, train_auprc: 0.9338, val_auprc: 0.9319
# scheduling
# Epoch: 136 (126.5337s), train_loss: 0.2846, val_loss: 0.2938, train_acc: 0.8795, val_acc:0.8755
# 		train_roc: 0.9479, val_roc: 0.9447, train_auprc: 0.9334, val_auprc: 0.9320
# scheduling
# Epoch: 137 (126.8894s), train_loss: 0.2838, val_loss: 0.2940, train_acc: 0.8796, val_acc:0.8752
# 		train_roc: 0.9483, val_roc: 0.9445, train_auprc: 0.9342, val_auprc: 0.9319
# scheduling
# Epoch: 138 (126.7143s), train_loss: 0.2844, val_loss: 0.2938, train_acc: 0.8791, val_acc:0.8751
# 		train_roc: 0.9481, val_roc: 0.9446, train_auprc: 0.9335, val_auprc: 0.9319
# scheduling
# Epoch: 139 (126.7646s), train_loss: 0.2848, val_loss: 0.2939, train_acc: 0.8790, val_acc:0.8752
# 		train_roc: 0.9479, val_roc: 0.9446, train_auprc: 0.9335, val_auprc: 0.9318
# scheduling
# Epoch: 140 (126.0485s), train_loss: 0.2838, val_loss: 0.2936, train_acc: 0.8796, val_acc:0.8752
# 		train_roc: 0.9483, val_roc: 0.9447, train_auprc: 0.9339, val_auprc: 0.9320
# scheduling
# Epoch: 141 (126.5975s), train_loss: 0.2847, val_loss: 0.2933, train_acc: 0.8790, val_acc:0.8757
# 		train_roc: 0.9479, val_roc: 0.9448, train_auprc: 0.9335, val_auprc: 0.9321
# scheduling
# Epoch: 142 (125.7637s), train_loss: 0.2847, val_loss: 0.2932, train_acc: 0.8792, val_acc:0.8754
# 		train_roc: 0.9479, val_roc: 0.9448, train_auprc: 0.9333, val_auprc: 0.9321
# scheduling
# Epoch: 143 (126.0765s), train_loss: 0.2844, val_loss: 0.2933, train_acc: 0.8805, val_acc:0.8753
# 		train_roc: 0.9480, val_roc: 0.9448, train_auprc: 0.9336, val_auprc: 0.9322
# scheduling
# Epoch: 144 (126.6042s), train_loss: 0.2848, val_loss: 0.2934, train_acc: 0.8796, val_acc:0.8755
# 		train_roc: 0.9479, val_roc: 0.9448, train_auprc: 0.9334, val_auprc: 0.9320
# scheduling
# Epoch: 145 (126.5891s), train_loss: 0.2841, val_loss: 0.2935, train_acc: 0.8804, val_acc:0.8755
# 		train_roc: 0.9482, val_roc: 0.9447, train_auprc: 0.9337, val_auprc: 0.9320
# scheduling
# Epoch: 146 (126.6103s), train_loss: 0.2842, val_loss: 0.2935, train_acc: 0.8796, val_acc:0.8754
# 		train_roc: 0.9481, val_roc: 0.9448, train_auprc: 0.9338, val_auprc: 0.9320
# scheduling
# Epoch: 147 (126.4747s), train_loss: 0.2834, val_loss: 0.2934, train_acc: 0.8808, val_acc:0.8753
# 		train_roc: 0.9484, val_roc: 0.9448, train_auprc: 0.9342, val_auprc: 0.9321
# scheduling
# Epoch: 148 (125.9796s), train_loss: 0.2847, val_loss: 0.2936, train_acc: 0.8797, val_acc:0.8755
# 		train_roc: 0.9479, val_roc: 0.9447, train_auprc: 0.9335, val_auprc: 0.9319
# scheduling
# Epoch: 149 (126.8538s), train_loss: 0.2845, val_loss: 0.2936, train_acc: 0.8798, val_acc:0.8750
# 		train_roc: 0.9480, val_roc: 0.9447, train_auprc: 0.9334, val_auprc: 0.9319
# scheduling
# Epoch: 150 (125.6816s), train_loss: 0.2841, val_loss: 0.2938, train_acc: 0.8796, val_acc:0.8747
# 		train_roc: 0.9482, val_roc: 0.9446, train_auprc: 0.9335, val_auprc: 0.9318
# scheduling
# Epoch: 151 (126.7359s), train_loss: 0.2846, val_loss: 0.2936, train_acc: 0.8787, val_acc:0.8753
# 		train_roc: 0.9479, val_roc: 0.9447, train_auprc: 0.9336, val_auprc: 0.9319
# scheduling
# Epoch: 152 (126.5822s), train_loss: 0.2840, val_loss: 0.2938, train_acc: 0.8803, val_acc:0.8751
# 		train_roc: 0.9482, val_roc: 0.9446, train_auprc: 0.9337, val_auprc: 0.9319
# scheduling
# Epoch: 153 (126.1680s), train_loss: 0.2841, val_loss: 0.2933, train_acc: 0.8792, val_acc:0.8758
# 		train_roc: 0.9481, val_roc: 0.9448, train_auprc: 0.9338, val_auprc: 0.9322
# scheduling
# Epoch: 154 (126.7110s), train_loss: 0.2843, val_loss: 0.2934, train_acc: 0.8795, val_acc:0.8755
# 		train_roc: 0.9481, val_roc: 0.9448, train_auprc: 0.9337, val_auprc: 0.9321
# scheduling
# Epoch: 155 (125.6357s), train_loss: 0.2841, val_loss: 0.2935, train_acc: 0.8796, val_acc:0.8756
# 		train_roc: 0.9482, val_roc: 0.9447, train_auprc: 0.9338, val_auprc: 0.9320
# scheduling
# Epoch: 156 (126.3399s), train_loss: 0.2841, val_loss: 0.2935, train_acc: 0.8792, val_acc:0.8754
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9338, val_auprc: 0.9320
# scheduling
# Epoch: 157 (126.5723s), train_loss: 0.2838, val_loss: 0.2935, train_acc: 0.8800, val_acc:0.8754
# 		train_roc: 0.9482, val_roc: 0.9447, train_auprc: 0.9339, val_auprc: 0.9320
# scheduling
# Epoch: 158 (126.4262s), train_loss: 0.2843, val_loss: 0.2933, train_acc: 0.8793, val_acc:0.8760
# 		train_roc: 0.9481, val_roc: 0.9448, train_auprc: 0.9335, val_auprc: 0.9321
# scheduling
# Epoch: 159 (126.3261s), train_loss: 0.2849, val_loss: 0.2936, train_acc: 0.8792, val_acc:0.8749
# 		train_roc: 0.9478, val_roc: 0.9447, train_auprc: 0.9333, val_auprc: 0.9320
# scheduling
# Epoch: 160 (126.5581s), train_loss: 0.2839, val_loss: 0.2935, train_acc: 0.8800, val_acc:0.8753
# 		train_roc: 0.9483, val_roc: 0.9447, train_auprc: 0.9336, val_auprc: 0.9320
# scheduling
# Epoch: 161 (126.5103s), train_loss: 0.2842, val_loss: 0.2934, train_acc: 0.8799, val_acc:0.8752
# 		train_roc: 0.9481, val_roc: 0.9448, train_auprc: 0.9337, val_auprc: 0.9320
# scheduling
# Epoch: 162 (126.4897s), train_loss: 0.2843, val_loss: 0.2932, train_acc: 0.8797, val_acc:0.8755
# 		train_roc: 0.9481, val_roc: 0.9448, train_auprc: 0.9336, val_auprc: 0.9321
# scheduling
# Epoch: 163 (126.5715s), train_loss: 0.2836, val_loss: 0.2933, train_acc: 0.8806, val_acc:0.8754
# 		train_roc: 0.9484, val_roc: 0.9448, train_auprc: 0.9340, val_auprc: 0.9321
# scheduling
# Epoch: 164 (125.3761s), train_loss: 0.2839, val_loss: 0.2932, train_acc: 0.8798, val_acc:0.8757
# 		train_roc: 0.9482, val_roc: 0.9448, train_auprc: 0.9341, val_auprc: 0.9322
# scheduling
# Epoch: 165 (126.8136s), train_loss: 0.2837, val_loss: 0.2934, train_acc: 0.8793, val_acc:0.8754
# 		train_roc: 0.9483, val_roc: 0.9448, train_auprc: 0.9339, val_auprc: 0.9321
# scheduling
# Epoch: 166 (126.5660s), train_loss: 0.2842, val_loss: 0.2934, train_acc: 0.8794, val_acc:0.8754
# 		train_roc: 0.9481, val_roc: 0.9448, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 167 (126.5381s), train_loss: 0.2835, val_loss: 0.2936, train_acc: 0.8798, val_acc:0.8754
# 		train_roc: 0.9484, val_roc: 0.9447, train_auprc: 0.9341, val_auprc: 0.9320
# scheduling
# Epoch: 168 (126.6310s), train_loss: 0.2841, val_loss: 0.2936, train_acc: 0.8805, val_acc:0.8753
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9338, val_auprc: 0.9320
# scheduling
# Epoch: 169 (125.3352s), train_loss: 0.2840, val_loss: 0.2934, train_acc: 0.8794, val_acc:0.8754
# 		train_roc: 0.9482, val_roc: 0.9448, train_auprc: 0.9337, val_auprc: 0.9320
# scheduling
# Epoch: 170 (126.5131s), train_loss: 0.2846, val_loss: 0.2933, train_acc: 0.8796, val_acc:0.8756
# 		train_roc: 0.9479, val_roc: 0.9448, train_auprc: 0.9335, val_auprc: 0.9321
# scheduling
# Epoch: 171 (125.9967s), train_loss: 0.2849, val_loss: 0.2933, train_acc: 0.8790, val_acc:0.8753
# 		train_roc: 0.9478, val_roc: 0.9448, train_auprc: 0.9333, val_auprc: 0.9321
# scheduling
# Epoch: 172 (126.6330s), train_loss: 0.2841, val_loss: 0.2933, train_acc: 0.8793, val_acc:0.8754
# 		train_roc: 0.9482, val_roc: 0.9448, train_auprc: 0.9339, val_auprc: 0.9321
# scheduling
# Epoch: 173 (126.4060s), train_loss: 0.2835, val_loss: 0.2932, train_acc: 0.8804, val_acc:0.8753
# 		train_roc: 0.9484, val_roc: 0.9449, train_auprc: 0.9341, val_auprc: 0.9322
# scheduling
# Epoch: 174 (126.9060s), train_loss: 0.2841, val_loss: 0.2933, train_acc: 0.8795, val_acc:0.8753
# 		train_roc: 0.9482, val_roc: 0.9448, train_auprc: 0.9337, val_auprc: 0.9321
# scheduling
# Epoch: 175 (126.2382s), train_loss: 0.2837, val_loss: 0.2933, train_acc: 0.8801, val_acc:0.8752
# 		train_roc: 0.9483, val_roc: 0.9448, train_auprc: 0.9340, val_auprc: 0.9321
# scheduling
# Epoch: 176 (126.2598s), train_loss: 0.2838, val_loss: 0.2932, train_acc: 0.8796, val_acc:0.8755
# 		train_roc: 0.9483, val_roc: 0.9448, train_auprc: 0.9339, val_auprc: 0.9321
# scheduling
# Epoch: 177 (126.7007s), train_loss: 0.2842, val_loss: 0.2930, train_acc: 0.8799, val_acc:0.8756
# 		train_roc: 0.9481, val_roc: 0.9449, train_auprc: 0.9337, val_auprc: 0.9323
# scheduling
# Epoch: 178 (126.6173s), train_loss: 0.2843, val_loss: 0.2932, train_acc: 0.8790, val_acc:0.8757
# 		train_roc: 0.9481, val_roc: 0.9449, train_auprc: 0.9336, val_auprc: 0.9321
# scheduling
# Epoch: 179 (126.8265s), train_loss: 0.2833, val_loss: 0.2931, train_acc: 0.8799, val_acc:0.8757
# 		train_roc: 0.9485, val_roc: 0.9449, train_auprc: 0.9341, val_auprc: 0.9322
# scheduling
# Epoch: 180 (126.3576s), train_loss: 0.2846, val_loss: 0.2931, train_acc: 0.8788, val_acc:0.8757
# 		train_roc: 0.9479, val_roc: 0.9449, train_auprc: 0.9335, val_auprc: 0.9322
# scheduling
# Epoch: 181 (126.3978s), train_loss: 0.2832, val_loss: 0.2930, train_acc: 0.8808, val_acc:0.8755
# 		train_roc: 0.9485, val_roc: 0.9449, train_auprc: 0.9342, val_auprc: 0.9322
# scheduling
# Epoch: 182 (126.7985s), train_loss: 0.2847, val_loss: 0.2932, train_acc: 0.8796, val_acc:0.8757
# 		train_roc: 0.9479, val_roc: 0.9448, train_auprc: 0.9337, val_auprc: 0.9322
# scheduling
# Epoch: 183 (126.4130s), train_loss: 0.2841, val_loss: 0.2934, train_acc: 0.8804, val_acc:0.8754
# 		train_roc: 0.9481, val_roc: 0.9448, train_auprc: 0.9339, val_auprc: 0.9321
# scheduling
# Epoch: 184 (125.5399s), train_loss: 0.2843, val_loss: 0.2936, train_acc: 0.8795, val_acc:0.8755
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9337, val_auprc: 0.9320
# scheduling
# Epoch: 185 (126.5789s), train_loss: 0.2845, val_loss: 0.2934, train_acc: 0.8794, val_acc:0.8755
# 		train_roc: 0.9480, val_roc: 0.9447, train_auprc: 0.9335, val_auprc: 0.9320
# scheduling
# Epoch: 186 (126.8850s), train_loss: 0.2839, val_loss: 0.2934, train_acc: 0.8800, val_acc:0.8758
# 		train_roc: 0.9483, val_roc: 0.9448, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 187 (126.2614s), train_loss: 0.2843, val_loss: 0.2934, train_acc: 0.8792, val_acc:0.8757
# 		train_roc: 0.9480, val_roc: 0.9448, train_auprc: 0.9336, val_auprc: 0.9320
# scheduling
# Epoch: 188 (126.4587s), train_loss: 0.2840, val_loss: 0.2935, train_acc: 0.8790, val_acc:0.8756
# 		train_roc: 0.9482, val_roc: 0.9447, train_auprc: 0.9338, val_auprc: 0.9320
# scheduling
# Epoch: 189 (125.7175s), train_loss: 0.2844, val_loss: 0.2935, train_acc: 0.8802, val_acc:0.8758
# 		train_roc: 0.9480, val_roc: 0.9447, train_auprc: 0.9337, val_auprc: 0.9320
# scheduling
# Epoch: 190 (126.3151s), train_loss: 0.2841, val_loss: 0.2935, train_acc: 0.8795, val_acc:0.8757
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9336, val_auprc: 0.9320
# scheduling
# Epoch: 191 (126.8724s), train_loss: 0.2840, val_loss: 0.2935, train_acc: 0.8799, val_acc:0.8757
# 		train_roc: 0.9482, val_roc: 0.9447, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 192 (125.8250s), train_loss: 0.2846, val_loss: 0.2933, train_acc: 0.8796, val_acc:0.8758
# 		train_roc: 0.9479, val_roc: 0.9448, train_auprc: 0.9336, val_auprc: 0.9321
# scheduling
# Epoch: 193 (126.4938s), train_loss: 0.2838, val_loss: 0.2935, train_acc: 0.8803, val_acc:0.8757
# 		train_roc: 0.9483, val_roc: 0.9447, train_auprc: 0.9339, val_auprc: 0.9320
# scheduling
# Epoch: 194 (126.2323s), train_loss: 0.2848, val_loss: 0.2934, train_acc: 0.8799, val_acc:0.8756
# 		train_roc: 0.9479, val_roc: 0.9447, train_auprc: 0.9333, val_auprc: 0.9321
# scheduling
# Epoch: 195 (126.2787s), train_loss: 0.2842, val_loss: 0.2935, train_acc: 0.8794, val_acc:0.8757
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9337, val_auprc: 0.9321
# scheduling
# Epoch: 196 (126.5821s), train_loss: 0.2838, val_loss: 0.2936, train_acc: 0.8796, val_acc:0.8758
# 		train_roc: 0.9483, val_roc: 0.9447, train_auprc: 0.9339, val_auprc: 0.9320
# scheduling
# Epoch: 197 (126.6807s), train_loss: 0.2845, val_loss: 0.2935, train_acc: 0.8793, val_acc:0.8759
# 		train_roc: 0.9480, val_roc: 0.9447, train_auprc: 0.9336, val_auprc: 0.9321
# scheduling
# Epoch: 198 (126.2348s), train_loss: 0.2847, val_loss: 0.2936, train_acc: 0.8801, val_acc:0.8757
# 		train_roc: 0.9479, val_roc: 0.9447, train_auprc: 0.9334, val_auprc: 0.9320
# scheduling
# Epoch: 199 (126.7788s), train_loss: 0.2842, val_loss: 0.2935, train_acc: 0.8787, val_acc:0.8757
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9336, val_auprc: 0.9321
# scheduling
# Epoch: 200 (126.4722s), train_loss: 0.2843, val_loss: 0.2935, train_acc: 0.8801, val_acc:0.8758
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9337, val_auprc: 0.9321
# scheduling
# Epoch: 201 (126.7482s), train_loss: 0.2849, val_loss: 0.2935, train_acc: 0.8793, val_acc:0.8758
# 		train_roc: 0.9478, val_roc: 0.9447, train_auprc: 0.9331, val_auprc: 0.9321
# scheduling
# Epoch: 202 (126.9306s), train_loss: 0.2841, val_loss: 0.2936, train_acc: 0.8793, val_acc:0.8759
# 		train_roc: 0.9482, val_roc: 0.9447, train_auprc: 0.9336, val_auprc: 0.9320
# scheduling
# Epoch: 203 (126.5906s), train_loss: 0.2842, val_loss: 0.2935, train_acc: 0.8797, val_acc:0.8758
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 204 (126.8087s), train_loss: 0.2838, val_loss: 0.2934, train_acc: 0.8798, val_acc:0.8760
# 		train_roc: 0.9483, val_roc: 0.9447, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 205 (126.5130s), train_loss: 0.2834, val_loss: 0.2936, train_acc: 0.8796, val_acc:0.8758
# 		train_roc: 0.9484, val_roc: 0.9447, train_auprc: 0.9342, val_auprc: 0.9320
# scheduling
# Epoch: 206 (126.5986s), train_loss: 0.2842, val_loss: 0.2934, train_acc: 0.8802, val_acc:0.8760
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9337, val_auprc: 0.9321
# scheduling
# Epoch: 207 (126.4532s), train_loss: 0.2835, val_loss: 0.2935, train_acc: 0.8795, val_acc:0.8758
# 		train_roc: 0.9484, val_roc: 0.9447, train_auprc: 0.9341, val_auprc: 0.9321
# scheduling
# Epoch: 208 (126.4131s), train_loss: 0.2843, val_loss: 0.2935, train_acc: 0.8793, val_acc:0.8761
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 209 (126.2532s), train_loss: 0.2843, val_loss: 0.2934, train_acc: 0.8791, val_acc:0.8760
# 		train_roc: 0.9481, val_roc: 0.9448, train_auprc: 0.9337, val_auprc: 0.9321
# scheduling
# Epoch: 210 (126.2824s), train_loss: 0.2834, val_loss: 0.2934, train_acc: 0.8799, val_acc:0.8759
# 		train_roc: 0.9484, val_roc: 0.9447, train_auprc: 0.9343, val_auprc: 0.9321
# scheduling
# Epoch: 211 (125.9814s), train_loss: 0.2842, val_loss: 0.2935, train_acc: 0.8800, val_acc:0.8758
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 212 (126.4222s), train_loss: 0.2834, val_loss: 0.2934, train_acc: 0.8800, val_acc:0.8758
# 		train_roc: 0.9484, val_roc: 0.9448, train_auprc: 0.9341, val_auprc: 0.9321
# scheduling
# Epoch: 213 (126.4890s), train_loss: 0.2838, val_loss: 0.2935, train_acc: 0.8792, val_acc:0.8759
# 		train_roc: 0.9483, val_roc: 0.9447, train_auprc: 0.9337, val_auprc: 0.9321
# scheduling
# Epoch: 214 (126.6980s), train_loss: 0.2842, val_loss: 0.2935, train_acc: 0.8801, val_acc:0.8759
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9336, val_auprc: 0.9321
# scheduling
# Epoch: 215 (125.3458s), train_loss: 0.2840, val_loss: 0.2935, train_acc: 0.8801, val_acc:0.8758
# 		train_roc: 0.9482, val_roc: 0.9447, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 216 (126.4957s), train_loss: 0.2844, val_loss: 0.2934, train_acc: 0.8794, val_acc:0.8758
# 		train_roc: 0.9480, val_roc: 0.9448, train_auprc: 0.9337, val_auprc: 0.9321
# scheduling
# Epoch: 217 (125.5317s), train_loss: 0.2840, val_loss: 0.2935, train_acc: 0.8797, val_acc:0.8757
# 		train_roc: 0.9482, val_roc: 0.9447, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 218 (126.5461s), train_loss: 0.2838, val_loss: 0.2932, train_acc: 0.8799, val_acc:0.8759
# 		train_roc: 0.9483, val_roc: 0.9448, train_auprc: 0.9338, val_auprc: 0.9322
# scheduling
# Epoch: 219 (126.2942s), train_loss: 0.2843, val_loss: 0.2934, train_acc: 0.8800, val_acc:0.8758
# 		train_roc: 0.9481, val_roc: 0.9448, train_auprc: 0.9337, val_auprc: 0.9321
# scheduling
# Epoch: 220 (126.8091s), train_loss: 0.2837, val_loss: 0.2935, train_acc: 0.8799, val_acc:0.8758
# 		train_roc: 0.9483, val_roc: 0.9447, train_auprc: 0.9339, val_auprc: 0.9321
# scheduling
# Epoch: 221 (126.5940s), train_loss: 0.2842, val_loss: 0.2935, train_acc: 0.8799, val_acc:0.8757
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9335, val_auprc: 0.9321
# scheduling
# Epoch: 222 (125.6933s), train_loss: 0.2845, val_loss: 0.2935, train_acc: 0.8795, val_acc:0.8758
# 		train_roc: 0.9480, val_roc: 0.9447, train_auprc: 0.9336, val_auprc: 0.9321
# scheduling
# Epoch: 223 (126.7019s), train_loss: 0.2835, val_loss: 0.2934, train_acc: 0.8796, val_acc:0.8758
# 		train_roc: 0.9484, val_roc: 0.9448, train_auprc: 0.9342, val_auprc: 0.9321
# scheduling
# Epoch: 224 (126.4938s), train_loss: 0.2839, val_loss: 0.2935, train_acc: 0.8801, val_acc:0.8757
# 		train_roc: 0.9482, val_roc: 0.9447, train_auprc: 0.9339, val_auprc: 0.9321
# scheduling
# Epoch: 225 (126.7676s), train_loss: 0.2833, val_loss: 0.2934, train_acc: 0.8800, val_acc:0.8757
# 		train_roc: 0.9485, val_roc: 0.9447, train_auprc: 0.9343, val_auprc: 0.9321
# scheduling
# Epoch: 226 (126.6280s), train_loss: 0.2835, val_loss: 0.2934, train_acc: 0.8793, val_acc:0.8758
# 		train_roc: 0.9484, val_roc: 0.9448, train_auprc: 0.9341, val_auprc: 0.9321
# scheduling
# Epoch: 227 (126.2558s), train_loss: 0.2841, val_loss: 0.2935, train_acc: 0.8803, val_acc:0.8757
# 		train_roc: 0.9482, val_roc: 0.9447, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 228 (126.0128s), train_loss: 0.2843, val_loss: 0.2933, train_acc: 0.8789, val_acc:0.8758
# 		train_roc: 0.9480, val_roc: 0.9448, train_auprc: 0.9336, val_auprc: 0.9322
# scheduling
# Epoch: 229 (126.9214s), train_loss: 0.2835, val_loss: 0.2934, train_acc: 0.8803, val_acc:0.8757
# 		train_roc: 0.9484, val_roc: 0.9448, train_auprc: 0.9340, val_auprc: 0.9321
# scheduling
# Epoch: 230 (126.4078s), train_loss: 0.2836, val_loss: 0.2935, train_acc: 0.8799, val_acc:0.8757
# 		train_roc: 0.9483, val_roc: 0.9447, train_auprc: 0.9340, val_auprc: 0.9321
# scheduling
# Epoch: 231 (126.3694s), train_loss: 0.2846, val_loss: 0.2935, train_acc: 0.8794, val_acc:0.8758
# 		train_roc: 0.9480, val_roc: 0.9447, train_auprc: 0.9335, val_auprc: 0.9321
# scheduling
# Epoch: 232 (126.1189s), train_loss: 0.2839, val_loss: 0.2934, train_acc: 0.8796, val_acc:0.8758
# 		train_roc: 0.9483, val_roc: 0.9448, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 233 (126.1301s), train_loss: 0.2843, val_loss: 0.2934, train_acc: 0.8801, val_acc:0.8758
# 		train_roc: 0.9481, val_roc: 0.9448, train_auprc: 0.9337, val_auprc: 0.9321
# scheduling
# Epoch: 234 (126.2502s), train_loss: 0.2839, val_loss: 0.2934, train_acc: 0.8796, val_acc:0.8758
# 		train_roc: 0.9482, val_roc: 0.9447, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 235 (126.4111s), train_loss: 0.2834, val_loss: 0.2935, train_acc: 0.8800, val_acc:0.8758
# 		train_roc: 0.9484, val_roc: 0.9447, train_auprc: 0.9342, val_auprc: 0.9321
# scheduling
# Epoch: 236 (125.8746s), train_loss: 0.2846, val_loss: 0.2934, train_acc: 0.8801, val_acc:0.8757
# 		train_roc: 0.9479, val_roc: 0.9448, train_auprc: 0.9335, val_auprc: 0.9321
# scheduling
# Epoch: 237 (126.8093s), train_loss: 0.2849, val_loss: 0.2934, train_acc: 0.8788, val_acc:0.8758
# 		train_roc: 0.9478, val_roc: 0.9447, train_auprc: 0.9333, val_auprc: 0.9321
# scheduling
# Epoch: 238 (126.0054s), train_loss: 0.2847, val_loss: 0.2935, train_acc: 0.8796, val_acc:0.8759
# 		train_roc: 0.9479, val_roc: 0.9447, train_auprc: 0.9335, val_auprc: 0.9321
# scheduling
# Epoch: 239 (126.7903s), train_loss: 0.2848, val_loss: 0.2935, train_acc: 0.8798, val_acc:0.8758
# 		train_roc: 0.9479, val_roc: 0.9447, train_auprc: 0.9332, val_auprc: 0.9321
# scheduling
# Epoch: 240 (126.3684s), train_loss: 0.2843, val_loss: 0.2935, train_acc: 0.8790, val_acc:0.8758
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9336, val_auprc: 0.9321
# scheduling
# Epoch: 241 (126.6701s), train_loss: 0.2843, val_loss: 0.2933, train_acc: 0.8794, val_acc:0.8759
# 		train_roc: 0.9480, val_roc: 0.9448, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 242 (125.8828s), train_loss: 0.2845, val_loss: 0.2935, train_acc: 0.8793, val_acc:0.8758
# 		train_roc: 0.9480, val_roc: 0.9447, train_auprc: 0.9335, val_auprc: 0.9321
# scheduling
# Epoch: 243 (126.7736s), train_loss: 0.2841, val_loss: 0.2934, train_acc: 0.8796, val_acc:0.8758
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9337, val_auprc: 0.9321
# scheduling
# Epoch: 244 (125.7650s), train_loss: 0.2840, val_loss: 0.2935, train_acc: 0.8803, val_acc:0.8758
# 		train_roc: 0.9482, val_roc: 0.9447, train_auprc: 0.9339, val_auprc: 0.9321
# scheduling
# Epoch: 245 (126.0731s), train_loss: 0.2833, val_loss: 0.2935, train_acc: 0.8798, val_acc:0.8758
# 		train_roc: 0.9485, val_roc: 0.9447, train_auprc: 0.9342, val_auprc: 0.9321
# scheduling
# Epoch: 246 (123.9693s), train_loss: 0.2842, val_loss: 0.2934, train_acc: 0.8801, val_acc:0.8757
# 		train_roc: 0.9482, val_roc: 0.9447, train_auprc: 0.9336, val_auprc: 0.9321
# scheduling
# Epoch: 247 (126.2597s), train_loss: 0.2842, val_loss: 0.2934, train_acc: 0.8791, val_acc:0.8760
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9336, val_auprc: 0.9321
# scheduling
# Epoch: 248 (126.4912s), train_loss: 0.2837, val_loss: 0.2934, train_acc: 0.8801, val_acc:0.8759
# 		train_roc: 0.9483, val_roc: 0.9448, train_auprc: 0.9340, val_auprc: 0.9321
# scheduling
# Epoch: 249 (126.5451s), train_loss: 0.2833, val_loss: 0.2935, train_acc: 0.8812, val_acc:0.8758
# 		train_roc: 0.9485, val_roc: 0.9447, train_auprc: 0.9341, val_auprc: 0.9321
# scheduling
# Epoch: 250 (126.1708s), train_loss: 0.2843, val_loss: 0.2936, train_acc: 0.8790, val_acc:0.8759
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9336, val_auprc: 0.9320
# scheduling
# Epoch: 251 (126.5754s), train_loss: 0.2841, val_loss: 0.2933, train_acc: 0.8798, val_acc:0.8758
# 		train_roc: 0.9482, val_roc: 0.9448, train_auprc: 0.9336, val_auprc: 0.9321
# scheduling
# Epoch: 252 (126.4401s), train_loss: 0.2837, val_loss: 0.2934, train_acc: 0.8802, val_acc:0.8758
# 		train_roc: 0.9483, val_roc: 0.9448, train_auprc: 0.9340, val_auprc: 0.9321
# scheduling
# Epoch: 253 (126.6714s), train_loss: 0.2842, val_loss: 0.2933, train_acc: 0.8796, val_acc:0.8760
# 		train_roc: 0.9481, val_roc: 0.9448, train_auprc: 0.9336, val_auprc: 0.9322
# scheduling
# Epoch: 254 (126.3550s), train_loss: 0.2848, val_loss: 0.2933, train_acc: 0.8792, val_acc:0.8758
# 		train_roc: 0.9478, val_roc: 0.9448, train_auprc: 0.9333, val_auprc: 0.9321
# scheduling
# Epoch: 255 (126.5219s), train_loss: 0.2840, val_loss: 0.2933, train_acc: 0.8802, val_acc:0.8758
# 		train_roc: 0.9482, val_roc: 0.9448, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 256 (126.3341s), train_loss: 0.2840, val_loss: 0.2932, train_acc: 0.8794, val_acc:0.8759
# 		train_roc: 0.9482, val_roc: 0.9448, train_auprc: 0.9338, val_auprc: 0.9322
# scheduling
# Epoch: 257 (126.7322s), train_loss: 0.2849, val_loss: 0.2935, train_acc: 0.8789, val_acc:0.8758
# 		train_roc: 0.9478, val_roc: 0.9447, train_auprc: 0.9332, val_auprc: 0.9321
# scheduling
# Epoch: 258 (126.6248s), train_loss: 0.2842, val_loss: 0.2934, train_acc: 0.8794, val_acc:0.8758
# 		train_roc: 0.9481, val_roc: 0.9448, train_auprc: 0.9337, val_auprc: 0.9321
# scheduling
# Epoch: 259 (126.3667s), train_loss: 0.2839, val_loss: 0.2936, train_acc: 0.8793, val_acc:0.8758
# 		train_roc: 0.9482, val_roc: 0.9447, train_auprc: 0.9339, val_auprc: 0.9320
# scheduling
# Epoch: 260 (127.3903s), train_loss: 0.2843, val_loss: 0.2935, train_acc: 0.8794, val_acc:0.8758
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9336, val_auprc: 0.9321
# scheduling
# Epoch: 261 (125.7477s), train_loss: 0.2838, val_loss: 0.2934, train_acc: 0.8800, val_acc:0.8759
# 		train_roc: 0.9483, val_roc: 0.9447, train_auprc: 0.9339, val_auprc: 0.9321
# scheduling
# Epoch: 262 (126.7738s), train_loss: 0.2840, val_loss: 0.2935, train_acc: 0.8794, val_acc:0.8758
# 		train_roc: 0.9482, val_roc: 0.9447, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 263 (125.7271s), train_loss: 0.2848, val_loss: 0.2934, train_acc: 0.8789, val_acc:0.8756
# 		train_roc: 0.9479, val_roc: 0.9447, train_auprc: 0.9333, val_auprc: 0.9321
# scheduling
# Epoch: 264 (126.5735s), train_loss: 0.2840, val_loss: 0.2934, train_acc: 0.8795, val_acc:0.8759
# 		train_roc: 0.9482, val_roc: 0.9448, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 265 (126.7961s), train_loss: 0.2841, val_loss: 0.2935, train_acc: 0.8800, val_acc:0.8759
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 266 (126.4975s), train_loss: 0.2847, val_loss: 0.2935, train_acc: 0.8797, val_acc:0.8760
# 		train_roc: 0.9479, val_roc: 0.9447, train_auprc: 0.9332, val_auprc: 0.9321
# scheduling
# Epoch: 267 (126.5556s), train_loss: 0.2847, val_loss: 0.2935, train_acc: 0.8792, val_acc:0.8758
# 		train_roc: 0.9479, val_roc: 0.9447, train_auprc: 0.9334, val_auprc: 0.9321
# scheduling
# Epoch: 268 (126.6548s), train_loss: 0.2841, val_loss: 0.2934, train_acc: 0.8795, val_acc:0.8758
# 		train_roc: 0.9481, val_roc: 0.9448, train_auprc: 0.9337, val_auprc: 0.9321
# scheduling
# Epoch: 269 (126.8802s), train_loss: 0.2844, val_loss: 0.2935, train_acc: 0.8794, val_acc:0.8758
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9335, val_auprc: 0.9320
# scheduling
# Epoch: 270 (126.2995s), train_loss: 0.2846, val_loss: 0.2935, train_acc: 0.8795, val_acc:0.8758
# 		train_roc: 0.9479, val_roc: 0.9447, train_auprc: 0.9335, val_auprc: 0.9321
# scheduling
# Epoch: 271 (126.0618s), train_loss: 0.2843, val_loss: 0.2935, train_acc: 0.8800, val_acc:0.8758
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9334, val_auprc: 0.9321
# scheduling
# Epoch: 272 (126.6776s), train_loss: 0.2836, val_loss: 0.2934, train_acc: 0.8798, val_acc:0.8760
# 		train_roc: 0.9483, val_roc: 0.9447, train_auprc: 0.9340, val_auprc: 0.9321
# scheduling
# Epoch: 273 (126.4152s), train_loss: 0.2831, val_loss: 0.2935, train_acc: 0.8804, val_acc:0.8756
# 		train_roc: 0.9486, val_roc: 0.9447, train_auprc: 0.9342, val_auprc: 0.9321
# scheduling
# Epoch: 274 (127.5124s), train_loss: 0.2840, val_loss: 0.2933, train_acc: 0.8798, val_acc:0.8757
# 		train_roc: 0.9482, val_roc: 0.9448, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 275 (126.6889s), train_loss: 0.2844, val_loss: 0.2935, train_acc: 0.8804, val_acc:0.8759
# 		train_roc: 0.9480, val_roc: 0.9447, train_auprc: 0.9336, val_auprc: 0.9321
# scheduling
# Epoch: 276 (126.1316s), train_loss: 0.2841, val_loss: 0.2933, train_acc: 0.8787, val_acc:0.8759
# 		train_roc: 0.9481, val_roc: 0.9448, train_auprc: 0.9339, val_auprc: 0.9321
# scheduling
# Epoch: 277 (126.4787s), train_loss: 0.2838, val_loss: 0.2935, train_acc: 0.8800, val_acc:0.8757
# 		train_roc: 0.9482, val_roc: 0.9447, train_auprc: 0.9340, val_auprc: 0.9321
# scheduling
# Epoch: 278 (126.7568s), train_loss: 0.2841, val_loss: 0.2934, train_acc: 0.8804, val_acc:0.8757
# 		train_roc: 0.9482, val_roc: 0.9448, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 279 (126.4621s), train_loss: 0.2847, val_loss: 0.2934, train_acc: 0.8789, val_acc:0.8758
# 		train_roc: 0.9479, val_roc: 0.9448, train_auprc: 0.9333, val_auprc: 0.9321
# scheduling
# Epoch: 280 (125.7865s), train_loss: 0.2843, val_loss: 0.2934, train_acc: 0.8794, val_acc:0.8758
# 		train_roc: 0.9481, val_roc: 0.9448, train_auprc: 0.9339, val_auprc: 0.9321
# scheduling
# Epoch: 281 (125.7914s), train_loss: 0.2842, val_loss: 0.2935, train_acc: 0.8799, val_acc:0.8758
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9337, val_auprc: 0.9321
# scheduling
# Epoch: 282 (126.4279s), train_loss: 0.2847, val_loss: 0.2934, train_acc: 0.8789, val_acc:0.8757
# 		train_roc: 0.9479, val_roc: 0.9447, train_auprc: 0.9332, val_auprc: 0.9321
# scheduling
# Epoch: 283 (125.8665s), train_loss: 0.2852, val_loss: 0.2933, train_acc: 0.8786, val_acc:0.8758
# 		train_roc: 0.9477, val_roc: 0.9448, train_auprc: 0.9330, val_auprc: 0.9321
# scheduling
# Epoch: 284 (127.0419s), train_loss: 0.2838, val_loss: 0.2934, train_acc: 0.8792, val_acc:0.8757
# 		train_roc: 0.9483, val_roc: 0.9447, train_auprc: 0.9340, val_auprc: 0.9321
# scheduling
# Epoch: 285 (126.5961s), train_loss: 0.2840, val_loss: 0.2933, train_acc: 0.8795, val_acc:0.8758
# 		train_roc: 0.9483, val_roc: 0.9448, train_auprc: 0.9337, val_auprc: 0.9321
# scheduling
# Epoch: 286 (126.5990s), train_loss: 0.2840, val_loss: 0.2933, train_acc: 0.8792, val_acc:0.8759
# 		train_roc: 0.9482, val_roc: 0.9448, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 287 (126.8652s), train_loss: 0.2843, val_loss: 0.2934, train_acc: 0.8803, val_acc:0.8759
# 		train_roc: 0.9481, val_roc: 0.9447, train_auprc: 0.9337, val_auprc: 0.9321
# scheduling
# Epoch: 288 (126.3163s), train_loss: 0.2844, val_loss: 0.2934, train_acc: 0.8797, val_acc:0.8758
# 		train_roc: 0.9480, val_roc: 0.9448, train_auprc: 0.9335, val_auprc: 0.9321
# scheduling
# Epoch: 289 (126.7292s), train_loss: 0.2839, val_loss: 0.2933, train_acc: 0.8796, val_acc:0.8759
# 		train_roc: 0.9482, val_roc: 0.9448, train_auprc: 0.9341, val_auprc: 0.9321
# scheduling
# Epoch: 290 (126.4225s), train_loss: 0.2835, val_loss: 0.2933, train_acc: 0.8795, val_acc:0.8757
# 		train_roc: 0.9484, val_roc: 0.9448, train_auprc: 0.9340, val_auprc: 0.9321
# scheduling
# Epoch: 291 (126.3788s), train_loss: 0.2842, val_loss: 0.2933, train_acc: 0.8795, val_acc:0.8758
# 		train_roc: 0.9481, val_roc: 0.9448, train_auprc: 0.9336, val_auprc: 0.9321
# scheduling
# Epoch: 292 (126.5424s), train_loss: 0.2843, val_loss: 0.2934, train_acc: 0.8794, val_acc:0.8758
# 		train_roc: 0.9481, val_roc: 0.9448, train_auprc: 0.9337, val_auprc: 0.9321
# scheduling
# Epoch: 293 (126.7336s), train_loss: 0.2838, val_loss: 0.2935, train_acc: 0.8802, val_acc:0.8759
# 		train_roc: 0.9483, val_roc: 0.9447, train_auprc: 0.9339, val_auprc: 0.9321
# scheduling
# Epoch: 294 (123.9820s), train_loss: 0.2836, val_loss: 0.2933, train_acc: 0.8801, val_acc:0.8759
# 		train_roc: 0.9484, val_roc: 0.9448, train_auprc: 0.9340, val_auprc: 0.9321
# scheduling
# Epoch: 295 (126.7658s), train_loss: 0.2845, val_loss: 0.2934, train_acc: 0.8799, val_acc:0.8757
# 		train_roc: 0.9480, val_roc: 0.9447, train_auprc: 0.9335, val_auprc: 0.9321
# scheduling
# Epoch: 296 (126.3379s), train_loss: 0.2840, val_loss: 0.2934, train_acc: 0.8799, val_acc:0.8759
# 		train_roc: 0.9482, val_roc: 0.9448, train_auprc: 0.9338, val_auprc: 0.9321
# scheduling
# Epoch: 297 (126.5749s), train_loss: 0.2839, val_loss: 0.2934, train_acc: 0.8796, val_acc:0.8759
# 		train_roc: 0.9482, val_roc: 0.9448, train_auprc: 0.9340, val_auprc: 0.9321
# scheduling
# Epoch: 298 (126.6544s), train_loss: 0.2841, val_loss: 0.2933, train_acc: 0.8798, val_acc:0.8758
# 		train_roc: 0.9481, val_roc: 0.9448, train_auprc: 0.9336, val_auprc: 0.9321
# scheduling
# Epoch: 299 (127.0412s), train_loss: 0.2837, val_loss: 0.2933, train_acc: 0.8804, val_acc:0.8759
# 		train_roc: 0.9483, val_roc: 0.9448, train_auprc: 0.9339, val_auprc: 0.9322
# scheduling
# Epoch: 300 (72.5376s), train_loss: 0.2834, val_loss: 0.2934, train_acc: 0.8798, val_acc:0.8759
# 		train_roc: 0.9484, val_roc: 0.9448, train_auprc: 0.9342, val_auprc: 0.9321
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
